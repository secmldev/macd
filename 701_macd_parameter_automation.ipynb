# %%
from mod_my_utils.read_write_data import *
from mod_macd_utils.macd import *

# %%
# data paramter
folder_path = 'data/'
stock_name = 'AAPL'
index_col = 'Date'
# macd parameters
short_window = 50
long_window = 200
signal_window = 30

# %%
macd_automated(folder_path, stock_name, index_col, short_window, long_window, signal_window)
# Out:
# stock name:  AAPL

# %%
short_windows = [20, 40, 100, 200]
long_windows = [50, 100, 200, 300]

# %%
pair = zip(short_windows, long_windows)
pair

# %%
items = zip(short_windows, long_windows)

# %%
for item in items:
    print(item)
    short_window = item[0]
    long_window = item[1]
    macd_automated(folder_path, stock_name, index_col, short_window, long_window, signal_window)
# Out:
# (20, 50)
# stock name:  AAPL
# (40, 100)
# stock name:  AAPL
# (100, 200)
# stock name:  AAPL
# (200, 300)
# stock name:  AAPL

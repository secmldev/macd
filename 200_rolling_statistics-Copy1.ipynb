# %% [markdown]
# [Rolling window](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rolling.html)

# %% [markdown]
# - moving window
# - average of moving window data

# %%
# inbuilt
import pandas as pd
import numpy as np
# user defined
from mod_my_utils.read_write_data import get_price_csv

# %%
folder_name = 'data/'
stock_name = 'ADBE'
index_col = 'Date'

# %%
stock_data = get_price_csv(folder_name, stock_name, index_col=index_col)
# Out:
# stock name:  ADBE

# %%
stock_data
# Out:
#               Open    High       Low   Close     Volume  Ex-Dividend  \
# Date
# 2007-12-03   41.87   43.10   41.8500   42.69  9153400.0          0.0
# 2007-12-04   42.22   43.65   42.2200   43.32  6540200.0          0.0
# 2007-12-05   43.93   44.29   43.6100   43.90  5883900.0          0.0
# 2007-12-06   44.20   44.64   43.7100   44.54  5545300.0          0.0
# 2007-12-07   44.30   44.54   43.8700   44.37  3709400.0          0.0
# ...            ...     ...       ...     ...        ...          ...
# 2017-11-27  184.83  185.84  184.0900  185.00  1273931.0          0.0
# 2017-11-28  185.62  186.27  184.3700  185.40  1624178.0          0.0
# 2017-11-29  183.87  184.73  175.3100  176.85  4230042.0          0.0
# 2017-11-30  178.14  181.67  176.5501  181.47  3890286.0          0.0
# 2017-12-01  179.51  182.00  177.1300  179.52  2997390.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# ...

# %%
stock_data.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 2007-12-03  41.87  43.10  41.85  42.69  9153400.0          0.0          1.0
# 2007-12-04  42.22  43.65  42.22  43.32  6540200.0          0.0          1.0
# 2007-12-05  43.93  44.29  43.61  43.90  5883900.0          0.0          1.0
# 2007-12-06  44.20  44.64  43.71  44.54  5545300.0          0.0          1.0
# 2007-12-07  44.30  44.54  43.87  44.37  3709400.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 2007-12-03      41.87      43.10     41.85       42.69    9153400.0
# 2007-12-04      42.22      43.65     42.22       43.32    6540200.0
# 2007-12-05      43.93      44.29     43.61       43.90    5883900.0
# 2007-12-06      44.20      44.64     43.71       44.54    5545300.0
# 2007-12-07      44.30      44.54     43.87       44.37    3709400.0

# %%
stock_data.tail()
# Out:
#               Open    High       Low   Close     Volume  Ex-Dividend  \
# Date
# 2017-11-27  184.83  185.84  184.0900  185.00  1273931.0          0.0
# 2017-11-28  185.62  186.27  184.3700  185.40  1624178.0          0.0
# 2017-11-29  183.87  184.73  175.3100  176.85  4230042.0          0.0
# 2017-11-30  178.14  181.67  176.5501  181.47  3890286.0          0.0
# 2017-12-01  179.51  182.00  177.1300  179.52  2997390.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2017-11-27          1.0     184.83     185.84  184.0900      185.00
# 2017-11-28          1.0     185.62     186.27  184.3700      185.40
# 2017-11-29          1.0     183.87     184.73  175.3100      176.85
# 2017-11-30          1.0     178.14     181.67  176.5501      181.47
# 2017-12-01          1.0     179.51     182.00  177.1300      179.52
#
#             Adj. Volume
# Date
# 2017-11-27    1273931.0
# 2017-11-28    1624178.0
# 2017-11-29    4230042.0
# ...

# %%
type(stock_data)
# Out:
# pandas.core.frame.DataFrame

# %%
stock_data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2517.000000  2517.000000  2517.000000  2517.000000  2.517000e+03
# mean     58.299552    58.901882    57.704974    58.346441  5.027467e+06
# std      35.750813    35.948643    35.530337    35.784670  4.366661e+06
# min      15.730000    16.480000    15.700000    15.980000  6.025050e+05
# 25%      32.360000    32.720000    32.010000    32.360000  2.504400e+06
# 50%      41.400000    41.930000    40.750000    41.400000  3.938000e+06
# 75%      78.420000    79.280000    77.820000    78.700000  6.345900e+06
# max     185.620000   186.270000   184.370000   185.400000  1.087524e+08
#
#        Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# count       2517.0       2517.0  2517.000000  2517.000000  2517.000000
# mean           0.0          1.0    58.299552    58.901882    57.704974
# std            0.0          0.0    35.750813    35.948643    35.530337
# ...

# %%
stock_data.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 2007-12-03  41.87  43.10  41.85  42.69  9153400.0          0.0          1.0
# 2007-12-04  42.22  43.65  42.22  43.32  6540200.0          0.0          1.0
# 2007-12-05  43.93  44.29  43.61  43.90  5883900.0          0.0          1.0
# 2007-12-06  44.20  44.64  43.71  44.54  5545300.0          0.0          1.0
# 2007-12-07  44.30  44.54  43.87  44.37  3709400.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 2007-12-03      41.87      43.10     41.85       42.69    9153400.0
# 2007-12-04      42.22      43.65     42.22       43.32    6540200.0
# 2007-12-05      43.93      44.29     43.61       43.90    5883900.0
# 2007-12-06      44.20      44.64     43.71       44.54    5545300.0
# 2007-12-07      44.30      44.54     43.87       44.37    3709400.0

# %%
stock_data[['Adj. Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data = stock_data[["Adj. Close"]].copy()
data.columns = ["Price"] 
data.head()
# Out:
#             Price
# Date
# 2007-12-03  42.69
# 2007-12-04  43.32
# 2007-12-05  43.90
# 2007-12-06  44.54
# 2007-12-07  44.37

# %%
data.head()
# Out:
#             Price
# Date
# 2007-12-03  42.69
# 2007-12-04  43.32
# 2007-12-05  43.90
# 2007-12-06  44.54
# 2007-12-07  44.37

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_data[['Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_data[['Volume']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
count
min
max
mean
median
std
percentile
correlation
mode
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2400/4263928032.py in <module>
# ----> 1 count
#       2 min
#       3 max
#       4 mean
#       5 median
#
# NameError: name 'count' is not defined

# %% [markdown]
# ### Basic statistics

# %%
data.count()
# Out:
# Price    2517
# dtype: int64

# %%
data
# Out:
#                  Price
# Date
# 2007-03-12   22.986003
# 2007-04-12   23.108091
# 2007-05-12   23.839335
# 2007-06-12   24.411582
# 2007-07-12   24.970258
# ...                ...
# 2017-11-27  174.090000
# 2017-11-28  173.070000
# 2017-11-29  169.480000
# 2017-11-30  171.850000
# 2017-01-12  171.050000
#
# [2517 rows x 1 columns]

# %%
stock_data.count()
# Out:
# Open           2517
# High           2517
# Low            2517
# Close          2517
# Volume         2517
# Ex-Dividend    2517
# Split Ratio    2517
# Adj. Open      2517
# Adj. High      2517
# Adj. Low       2517
# Adj. Close     2517
# Adj. Volume    2517
# dtype: int64

# %%
data
# Out:
#                  Price
# Date
# 2007-03-12   22.986003
# 2007-04-12   23.108091
# 2007-05-12   23.839335
# 2007-06-12   24.411582
# 2007-07-12   24.970258
# ...                ...
# 2017-11-27  174.090000
# 2017-11-28  173.070000
# 2017-11-29  169.480000
# 2017-11-30  171.850000
# 2017-01-12  171.050000
#
# [2517 rows x 1 columns]

# %%
data.max()
# Out:
# Price    175.88
# dtype: float64

# %%
data.std()
# Out:
# Price    41.256543
# dtype: float64

# %%
data.median()
# Out:
# Price    66.541004
# dtype: float64

# %%
data.mean()
# Out:
# Price    69.521432
# dtype: float64

# %%
data.mean()
# Out:
# Price    69.521432
# dtype: float64

# %%
data.max()
# Out:
# Price    175.88
# dtype: float64

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data
# Out:
#              Price
# Date
# 2007-12-03   42.69
# 2007-12-04   43.32
# 2007-12-05   43.90
# 2007-12-06   44.54
# 2007-12-07   44.37
# ...            ...
# 2017-11-27  185.00
# 2017-11-28  185.40
# 2017-11-29  176.85
# 2017-11-30  181.47
# 2017-12-01  179.52
#
# [2517 rows x 1 columns]

# %%
data.corr()
# Out:
#        Price
# Price    1.0

# %%
stock_data.corr()
# Out:
#                  Open      High       Low     Close    Volume  Ex-Dividend  \
# Open         1.000000  0.999857  0.999831  0.999708 -0.406879          NaN
# High         0.999857  1.000000  0.999798  0.999858 -0.403713          NaN
# Low          0.999831  0.999798  1.000000  0.999871 -0.410477          NaN
# Close        0.999708  0.999858  0.999871  1.000000 -0.407280          NaN
# Volume      -0.406879 -0.403713 -0.410477 -0.407280  1.000000          NaN
# Ex-Dividend       NaN       NaN       NaN       NaN       NaN          NaN
# Split Ratio       NaN       NaN       NaN       NaN       NaN          NaN
# Adj. Open    1.000000  0.999857  0.999831  0.999708 -0.406879          NaN
# Adj. High    0.999857  1.000000  0.999798  0.999858 -0.403713          NaN
# Adj. Low     0.999831  0.999798  1.000000  0.999871 -0.410477          NaN
# Adj. Close   0.999708  0.999858  0.999871  1.000000 -0.407280          NaN
# ...

# %%
data.min()
# Out:
# Price    15.98
# dtype: float64

# %%
data.median()
# Out:
# Price    66.541004
# dtype: float64

# %%
data.corr()
# Out:
#        Price
# Price    1.0

# %%
data.std()
# Out:
# Price    41.256543
# dtype: float64

# %%
statistics
rolling window
rolling statistics

# %% [markdown]
# ### Rolling window

# %%
data
# Out:
#              Price
# Date
# 2007-12-03   42.69
# 2007-12-04   43.32
# 2007-12-05   43.90
# 2007-12-06   44.54
# 2007-12-07   44.37
# ...            ...
# 2017-11-27  185.00
# 2017-11-28  185.40
# 2017-11-29  176.85
# 2017-11-30  181.47
# 2017-12-01  179.52
#
# [2517 rows x 1 columns]

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data.mean()
# Out:
# Price    58.346441
# dtype: float64

# %%
data.head(10)
# Out:
#               Price
# Date
# 2007-12-03  42.6900
# 2007-12-04  43.3200
# 2007-12-05  43.9000
# 2007-12-06  44.5400
# 2007-12-07  44.3700
# 2007-12-10  44.6200
# 2007-12-11  43.2699
# 2007-12-12  43.5400
# 2007-12-13  43.9000
# 2007-12-14  42.1100

# %%
data.rolling(5).mean()
# Out:
#               Price
# Date
# 2007-12-03      NaN
# 2007-12-04      NaN
# 2007-12-05      NaN
# 2007-12-06      NaN
# 2007-12-07   43.764
# ...             ...
# 2017-11-27  183.770
# 2017-11-28  184.382
# 2017-11-29  182.922
# 2017-11-30  182.636
# 2017-12-01  181.648
#
# [2517 rows x 1 columns]

# %%
data.head(5)
# Out:
#             Price
# Date
# 2007-12-03  42.69
# 2007-12-04  43.32
# 2007-12-05  43.90
# 2007-12-06  44.54
# 2007-12-07  44.37

# %%
data.head(20).rolling(5, min_periods=1).mean()
# Out:
#                 Price
# Date
# 2007-12-03  42.690000
# 2007-12-04  43.005000
# 2007-12-05  43.303333
# 2007-12-06  43.612500
# 2007-12-07  43.764000
# 2007-12-10  44.150000
# 2007-12-11  44.139980
# 2007-12-12  44.067980
# 2007-12-13  43.939980
# 2007-12-14  43.487980
# 2007-12-17  42.743980
# 2007-12-18  42.496000
# 2007-12-19  42.162000
# 2007-12-20  41.816000
# 2007-12-21  41.830000
# 2007-12-24  42.218000
# 2007-12-26  42.436000
# 2007-12-27  42.530000
# 2007-12-28  42.682000
# 2007-12-31  42.792000

# %%
data.head(20).rolling(5, min_periods=3).median()
# Out:
#               Price
# Date
# 2007-12-03      NaN
# 2007-12-04      NaN
# 2007-12-05  43.3200
# 2007-12-06  43.6100
# 2007-12-07  43.9000
# 2007-12-10  44.3700
# 2007-12-11  44.3700
# 2007-12-12  44.3700
# 2007-12-13  43.9000
# 2007-12-14  43.5400
# 2007-12-17  43.2699
# 2007-12-18  42.1100
# 2007-12-19  42.0300
# 2007-12-20  42.0300
# 2007-12-21  42.0300
# 2007-12-24  42.1700
# 2007-12-26  42.1800
# 2007-12-27  42.3400
# 2007-12-28  42.8400
# 2007-12-31  42.8400

# %%
data.head(20).rolling(5, min_periods=3).min()
# Out:
#               Price
# Date
# 2007-12-03      NaN
# 2007-12-04      NaN
# 2007-12-05  42.6900
# 2007-12-06  42.6900
# 2007-12-07  42.6900
# 2007-12-10  43.3200
# 2007-12-11  43.2699
# 2007-12-12  43.2699
# 2007-12-13  43.2699
# 2007-12-14  42.1100
# 2007-12-17  40.9000
# 2007-12-18  40.9000
# 2007-12-19  40.9000
# 2007-12-20  40.9000
# 2007-12-21  40.9000
# 2007-12-24  41.8700
# 2007-12-26  41.8700
# 2007-12-27  42.1700
# 2007-12-28  42.1800
# 2007-12-31  42.3400

# %%
data.head(20).rolling(5, min_periods=3).max()
# Out:
#             Price
# Date
# 2007-12-03    NaN
# 2007-12-04    NaN
# 2007-12-05  43.90
# 2007-12-06  44.54
# 2007-12-07  44.54
# 2007-12-10  44.62
# 2007-12-11  44.62
# 2007-12-12  44.62
# 2007-12-13  44.62
# 2007-12-14  44.62
# 2007-12-17  43.90
# 2007-12-18  43.90
# 2007-12-19  43.90
# 2007-12-20  42.17
# 2007-12-21  42.18
# 2007-12-24  42.84
# 2007-12-26  43.12
# 2007-12-27  43.12
# 2007-12-28  43.12
# 2007-12-31  43.12

# %%
data.head(20).rolling(5, min_periods=3).count()
# Out:
#             Price
# Date
# 2007-12-03    NaN
# 2007-12-04    NaN
# 2007-12-05    3.0
# 2007-12-06    4.0
# 2007-12-07    5.0
# 2007-12-10    5.0
# 2007-12-11    5.0
# 2007-12-12    5.0
# 2007-12-13    5.0
# 2007-12-14    5.0
# 2007-12-17    5.0
# 2007-12-18    5.0
# 2007-12-19    5.0
# 2007-12-20    5.0
# 2007-12-21    5.0
# 2007-12-24    5.0
# 2007-12-26    5.0
# 2007-12-27    5.0
# 2007-12-28    5.0
# 2007-12-31    5.0

# %%
data.head(20).rolling(5, min_periods=3).std()
# Out:
#                Price
# Date
# 2007-12-03       NaN
# 2007-12-04       NaN
# 2007-12-05  0.605172
# 2007-12-06  0.791512
# 2007-12-07  0.764611
# 2007-12-10  0.541479
# 2007-12-11  0.560797
# 2007-12-12  0.619362
# 2007-12-13  0.560788
# 2007-12-14  0.921998
# 2007-12-17  1.229717
# 2007-12-18  1.222142
# 2007-12-19  1.086126
# 2007-12-20  0.524290
# 2007-12-21  0.534930
# 2007-12-24  0.369824
# 2007-12-26  0.521469
# 2007-12-27  0.427902
# 2007-12-28  0.402269
# 2007-12-31  0.290293

# %%
data.rolling(window=6)
# Out:
# Rolling [window=6,center=False,axis=0,method=single]

# %% [markdown]
# # Moving Average

# %%
moving_average_5days = data.rolling(5, min_periods=1).mean()

# %%
moving_average_10days = data.rolling(10, min_periods=1).mean()

# %%
5, 10, 20, 50, 100, 200, 400

# %%
moving_average_400days

# %%
moving_average_10days
# Out:
#                 Price
# Date
# 2007-12-03  42.690000
# 2007-12-04  43.005000
# 2007-12-05  43.303333
# 2007-12-06  43.612500
# 2007-12-07  43.764000
# 2007-12-10  44.150000
# 2007-12-11  44.139980
# 2007-12-12  44.067980
# 2007-12-13  43.939980
# 2007-12-14  43.487980
# 2007-12-17  42.743980
# 2007-12-18  42.496000
# 2007-12-19  42.162000
# 2007-12-20  41.816000
# 2007-12-21  41.830000
# 2007-12-24  42.218000
# 2007-12-26  42.436000
# 2007-12-27  42.530000
# 2007-12-28  42.682000
# 2007-12-31  42.792000

# %%
moving_average_5days
# Out:
#                  Price
# Date
# 2007-12-03   42.690000
# 2007-12-04   43.005000
# 2007-12-05   43.303333
# 2007-12-06   43.612500
# 2007-12-07   43.764000
# ...                ...
# 2017-11-27  183.770000
# 2017-11-28  184.382000
# 2017-11-29  182.922000
# 2017-11-30  182.636000
# 2017-12-01  181.648000
#
# [2517 rows x 1 columns]

# %%
data.head()
# Out:
#             Price
# Date
# 2007-12-03  42.69
# 2007-12-04  43.32
# 2007-12-05  43.90
# 2007-12-06  44.54
# 2007-12-07  44.37

# %%
data['MA50'] = data['Price'].rolling(window=50, min_periods=4).mean()

# %%
data.head(10)
# Out:
#               Price       MA50  MA100
# Date
# 2007-12-03  42.6900        NaN    NaN
# 2007-12-04  43.3200        NaN    NaN
# 2007-12-05  43.9000        NaN    NaN
# 2007-12-06  44.5400  43.612500    NaN
# 2007-12-07  44.3700  43.764000    NaN
# 2007-12-10  44.6200  43.906667    NaN
# 2007-12-11  43.2699  43.815700    NaN
# 2007-12-12  43.5400  43.781237    NaN
# 2007-12-13  43.9000  43.794433    NaN
# 2007-12-14  42.1100  43.625990    NaN

# %%
data['MA100'] = data['Price'].rolling(window=100, min_periods=4).mean()

# %%
data.head(52)
# Out:
#               Price       MA50      MA100
# Date
# 2007-12-03  42.6900        NaN        NaN
# 2007-12-04  43.3200        NaN        NaN
# 2007-12-05  43.9000        NaN        NaN
# 2007-12-06  44.5400  43.612500  43.612500
# 2007-12-07  44.3700  43.764000  43.764000
# 2007-12-10  44.6200  43.906667  43.906667
# 2007-12-11  43.2699  43.815700  43.815700
# 2007-12-12  43.5400  43.781237  43.781237
# 2007-12-13  43.9000  43.794433  43.794433
# 2007-12-14  42.1100  43.625990  43.625990
# 2007-12-17  40.9000  43.378173  43.378173
# 2007-12-18  42.0300  43.265825  43.265825
# 2007-12-19  41.8700  43.158454  43.158454
# 2007-12-20  42.1700  43.087850  43.087850
# 2007-12-21  42.1800  43.027327  43.027327
# 2007-12-24  42.8400  43.015619  43.015619
# 2007-12-26  43.1200  43.021759  43.021759
# 2007-12-27  42.3400  42.983883  42.983883
# 2007-12-28  42.9300  42.981047  42.981047
# 2007-12-31  42.7300  42.968495  42.968495
# 2008-01-02  41.7100  42.908567  42.908567
# ...

# %%
data.head(50).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data['Price'].rolling(5).max().head(10)
# Out:
# Date
# 2007-12-03      NaN
# 2007-12-04      NaN
# 2007-12-05      NaN
# 2007-12-06      NaN
# 2007-12-07    44.54
# 2007-12-10    44.62
# 2007-12-11    44.62
# 2007-12-12    44.62
# 2007-12-13    44.62
# 2007-12-14    44.62
# Name: Price, dtype: float64

# %%
data['Price'].rolling(5).min().head(10)
# Out:
# Date
# 2007-12-03        NaN
# 2007-12-04        NaN
# 2007-12-05        NaN
# 2007-12-06        NaN
# 2007-12-07    42.6900
# 2007-12-10    43.3200
# 2007-12-11    43.2699
# 2007-12-12    43.2699
# 2007-12-13    43.2699
# 2007-12-14    42.1100
# Name: Price, dtype: float64

# %%
data['Price'].rolling(5).std().head(10)
# Out:
# Date
# 2007-12-03         NaN
# 2007-12-04         NaN
# 2007-12-05         NaN
# 2007-12-06         NaN
# 2007-12-07    0.764611
# 2007-12-10    0.541479
# 2007-12-11    0.560797
# 2007-12-12    0.619362
# 2007-12-13    0.560788
# 2007-12-14    0.921998
# Name: Price, dtype: float64

# %%
data['Price'].rolling(5).median().head(10)
# Out:
# Date
# 2007-12-03      NaN
# 2007-12-04      NaN
# 2007-12-05      NaN
# 2007-12-06      NaN
# 2007-12-07    43.90
# 2007-12-10    44.37
# 2007-12-11    44.37
# 2007-12-12    44.37
# 2007-12-13    43.90
# 2007-12-14    43.54
# Name: Price, dtype: float64

# %% [markdown]
# # center

# %%
data['Price'].rolling(5, center=True).median().head(10)
# Out:
# Date
# 2007-12-03        NaN
# 2007-12-04        NaN
# 2007-12-05    43.9000
# 2007-12-06    44.3700
# 2007-12-07    44.3700
# 2007-12-10    44.3700
# 2007-12-11    43.9000
# 2007-12-12    43.5400
# 2007-12-13    43.2699
# 2007-12-14    42.1100
# Name: Price, dtype: float64

# %%
data['Price'].head(10).rolling(5, center=True).median()
# Out:
# Date
# 2007-12-03      NaN
# 2007-12-04      NaN
# 2007-12-05    43.90
# 2007-12-06    44.37
# 2007-12-07    44.37
# 2007-12-10    44.37
# 2007-12-11    43.90
# 2007-12-12    43.54
# 2007-12-13      NaN
# 2007-12-14      NaN
# Name: Price, dtype: float64

# %%
# window, 
# min_periods=None, 
# center=False, 
# win_type=None, 
# on=None, 
# axis=0, 
# losed=None, 
# step=None, 
# method='single'

# %%
data.head()
# Out:
#             Price     MA50    MA100
# Date
# 2007-12-03  42.69      NaN      NaN
# 2007-12-04  43.32      NaN      NaN
# 2007-12-05  43.90      NaN      NaN
# 2007-12-06  44.54  43.6125  43.6125
# 2007-12-07  44.37  43.7640  43.7640

# %%
data['std50']= data['Price'].rolling(window=50, min_periods=4).std()

# %%
data.head()
# Out:
#             Price     MA50    MA100     std50
# Date
# 2007-12-03  42.69      NaN      NaN       NaN
# 2007-12-04  43.32      NaN      NaN       NaN
# 2007-12-05  43.90      NaN      NaN       NaN
# 2007-12-06  44.54  43.6125  43.6125  0.791512
# 2007-12-07  44.37  43.7640  43.7640  0.764611

# %%
https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html
# Out:
#   File "C:\Users\harih\AppData\Local\Temp/ipykernel_2400/2527825679.py", line 1
#     https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html
#           ^
# SyntaxError: invalid syntax

# %%
data['short_ewm_10'] = data['Price'].ewm(span=10, adjust=False).mean()
data['long_ewm_20'] = data['Price'].ewm(span=20, adjust=False).mean()
data.head()
# Out:
#             Price     MA50    MA100     std50  short_ewm_10  long_ewm_20
# Date
# 2007-12-03  42.69      NaN      NaN       NaN     42.690000    42.690000
# 2007-12-04  43.32      NaN      NaN       NaN     42.804545    42.750000
# 2007-12-05  43.90      NaN      NaN       NaN     43.003719    42.859524
# 2007-12-06  44.54  43.6125  43.6125  0.791512     43.283043    43.019569
# 2007-12-07  44.37  43.7640  43.7640  0.764611     43.480671    43.148182

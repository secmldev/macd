# %%
from mod_my_utils.read_write_data import *

# %%
from mod_macd_utils.macd import *

# %%
symbols = ['AAPL', 'ADBE', 'AMD', 'EBAY', 'HPQ', 'IBM', 'JNPR', 'MSFT', 'QCOM', 'AAPL', 'ADBE', 'AMD',]

# %%
# data realted parameters
folder_path = 'data/'
index_col = 'Date'
# macd parameters
short_window = 20
long_window = 50
signal_window = 12

# %%
macd_automated_multiple_stocks(symbols, folder_path, index_col, short_window, long_window, signal_window)
# Out:
# stock name:  AAPL
# stock name:  ADBE
# stock name:  AMD
# stock name:  EBAY
# stock name:  HPQ
# stock name:  IBM
# stock name:  JNPR
# stock name:  MSFT
# stock name:  QCOM
# stock name:  AAPL
# stock name:  ADBE
# stock name:  AMD
